# %%
import pandas as pd
import numpy as np
import csv
import json

# %% [markdown]
# Combination

# %%
def combination(k, n):
    if k == 0 or k == n:
        return 1
    if k == 1:
        return n
    return combination(k - 1, n - 1) + combination(k, n - 1)

# %% [markdown]
# Calcutelate matrix A

# %%
def calculateA(base):
    colum = len(base[0])
    row = len(base)
    A = np.zeros((row, combination(4, colum - 1)))

    for r1 in range(row):
        k = [0] * combination(4, colum - 1)
        temp = 0
        for a in range(0, colum - 4):
            for b in range(a + 1, colum - 3):
                for c in range(b + 1, colum - 2):
                    for d in range(c + 1, colum - 1):
                        for r2 in range(row):
                            if base[r1][a] == base[r2][a] and base[r1][b] == base[r2][b] and base[r1][c] == base[r2][c] and base[r1][d] == base[r2][d]:
                                k[temp] += 1

                        A[r1][temp] = k[temp] / row
                        temp += 1
    print("done A")
    return A

# %% [markdown]
# Calcutelate matrix M

# %%
def calculateM(base):
    colum = len(base[0])
    row = len(base)
    M = np.zeros((row, colum - 1))
    for t1 in range(row):
        k = [0] * (colum - 1)
        temp = 0
        for i in range(colum - 1):
            for t2 in range(row):
                if base[t1][i] == base[t2][i] and base[t1][colum - 1] == base[t2][colum - 1]:
                    k[temp] += 1
            M[t1][temp] = k[temp] / row
            temp += 1
    return M

# %% [markdown]
# Calcutelate matrix B

# %%
def calculateB(base, A, M):
    colum = len(base[0])
    row = len(base)
    B = np.zeros((row, combination(3, colum - 1)))

    for r in range(row):
        temp = 0
        for a in range(0, colum - 3):
            for b in range(a + 1, colum - 2):
                for c in range(b + 1, colum - 1):
                    B[r][temp] = sum(A[r]) * min(M[r][a], M[r][b], M[r][c])
                    temp += 1
    print("done B")
    return B

# %% [markdown]
# Calcutelate matrix C

# %%
 def calculateC(base, B):
    colum = len(base[0])
    row = len(base)
    cols = 6 * combination(3, colum - 1)
    C = np.zeros((row, cols))

    for r1 in range(row):
        temp = 0
        for i in range(1,7):
            for a in range(0, (colum - 3)):
                for b in range(a + 1, (colum - 2)):
                    for c in range(b + 1, (colum - 1)):
                        for r2 in range(row):
                            if base[r1][a] == base[r2][a] and base[r1][b] == base[r2][b] and base[r1][c] == base[r2][c] and base[r2][colum - 1] == i:
                                C[r1][temp] += B[r2][temp % combination(3, colum - 1)]
                        temp += 1
    print("done C")
    return C

# %% [markdown]
# Calcutelate FISA

# %%
def FISA(base, C, list):
    colum = len(base[0])
    row = len(base)

    cols = combination(3, (colum - 1))
    C0 = [0] * cols
    C1 = [0] * cols
    C2 = [0] * cols
    C3 = [0] * cols
    C4 = [0] * cols
    C5 = [0] * cols

    t = 0
    for a in range(0, colum - 3):
        for b in range(a + 1, colum - 2):
            for c in range(b + 1, colum - 1):
                for r in range(row-1):
                    if base[r][a] == list[a] and base[r][b] == list[b] and base[r][c] == list[c] and base[r][colum-1] == 1:
                        C0[t] = C[r][t + 0 * cols]
                    if base[r][a] == list[a] and base[r][b] == list[b] and base[r][c] == list[c] and base[r][colum-1] == 2:
                        C1[t] = C[r][t + 1 * cols]
                    if base[r][a] == list[a] and base[r][b] == list[b] and base[r][c] == list[c] and base[r][colum-1] == 3:
                        C2[t] = C[r][t + 2 * cols]
                    if base[r][a] == list[a] and base[r][b] == list[b] and base[r][c] == list[c] and base[r][colum-1] == 4:
                        C3[t] = C[r][t + 3 * cols]
                    if base[r][a] == list[a] and base[r][b] == list[b] and base[r][c] == list[c] and base[r][colum-1] == 5:
                        C4[t] = C[r][t + 4 * cols]
                    if base[r][a] == list[a] and base[r][b] == list[b] and base[r][c] == list[c] and base[r][colum-1] == 6:
                        C5[t] = C[r][t + 5 * cols]
                t += 1

    D0 = max(C0) + min(C0)
    D1 = max(C1) + min(C1)
    D2 = max(C2) + min(C2)
    D3 = max(C3) + min(C3)
    D4 = max(C4) + min(C4)
    D5 = max(C5) + min(C5)
    
    DARR = [D0,D1,D2,D3,D4,D5]
    
    return DARR.index(max(DARR)) + 1, max(DARR)/sum(DARR)

# %% [markdown]
# Acc_precision_recall

# %%
def Acc(A,B):
    result = 0
    B = [int(float(x)) for x in B]

    for i in range(len(A)):
        if int(A[i]) - int(B[i]) == 0:
            result += 1

    return round(result*100/len(A), 2)


def Tprecision(Pre, Act):
    TP = {}
    FP = {}
    unique_labels = set(Act) | set(Pre)
    for label in unique_labels:
        TP[label] = 0
        FP[label] = 0

    for i in range(len(Pre)):
        pred_label = int(Pre[i])
        true_label = int(Act[i])

        if pred_label == true_label:
            TP[pred_label] += 1
        else:
            FP[pred_label] += 1

    label_precision = {}
    for label in unique_labels:
        if TP[label] + FP[label] > 0:
            label_precision[label] = round(100 * TP[label] / (TP[label] + FP[label]), 2)
        else:
            label_precision[label] = 0
    print(label_precision)
    return label_precision


def Trecall(Pre, Act):
    TP = {}
    FN = {}
    unique_labels = set(Act) | set(Pre)

    for label in unique_labels:
        TP[label] = 0
        FN[label] = 0

    for i in range(len(Pre)):
        pred_label = int(Pre[i])
        true_label = int(Act[i])

        if pred_label == true_label:
            TP[true_label] += 1
        else:
            FN[true_label] += 1

    label_recall = {}
    for label in unique_labels:
        if TP[label] + FN[label] > 0:
            label_recall[label] = round(100 * TP[label] / (TP[label] + FN[label]), 2)
        else:
            label_recall[label] = 0

    return label_recall


def testAccuracy(base,Te,C):
    test = Te
    X = np.zeros(len(test))
    ddd = np.zeros(len(test))
    X_test = np.array(test).T[-1]
    for i in range(len(test)):
        X[i], ddd[i] = FISA(base, C, test[i])
        listRank.append(ddd[i])
       
    res.append(X)
    listAcc.append(Acc(X,X_test))
    # listPre = list(Tprecision(X, X_test).values())
    # listRe = list(Trecall(X, X_test).values())

# %% [markdown]
# Train_test model

# %%
from sklearn.model_selection import train_test_split
# df = pd.read_csv('/kaggle/input/test-lab/test.csv')
# Y = df['Outcome']
# traindf, testdf = train_test_split(df,test_size=0.2, random_state=None)
traindf = pd.read_csv('/kaggle/input/dataonlyrp/TrainDataRule.csv')
testdf = pd.read_csv('/kaggle/input/dataonlyrp/TestDataRule.csv')
base = traindf.values.tolist()
test = testdf.values.tolist()
print(len(base))
print(base)
# Out:
# 780
# [['Low', 'Low', 'Medium', 'Medium', 'High', 'Low', 'Low', 'High', 'High', 'High', 'High', 'Low', 'Very High', 'Low', 'Medium', 'High', 'High', 'Low', 'Low', 'Low', 'High', 'High', 3.0], ['Low', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low', 'Very High', 'Low', 'Medium', 'Low', 'Medium', 'Low', 'Low', 'Low', 'Low', 'Low', 4.0], ['Low', 'Low', 'Medium', 'Medium', 'Medium', 'Low', 'Low', 'Low', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'Low', 'High', 'Low', 'High', 'High', 1.0], ['Low', 'Low', 'Low', 'Low', 'High', 'Low', 'High', 'High', 'High', 'High', 'High', 'Low', 'Very Low', 'Low', 'Low', 'High', 'Low', 'Low', 'Low', 'Low', 'High', 'High', 1.0], ['Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low', 'Very Low', 'Low', 'Medium', 'High', 'Medium', 'Low', 'Low', 'Low', 'Low', 'Low', 3.0], ['Low', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Low', 'High', 'High', 'High', 'High', 'Medium', 'Very High', 'Low', 'Medium', 'High', 'High', 'Low', 'High', 'Low', 'High', 'High', 2.0], ['Low', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low', 'High', 'Low', 'Medium', 'High', 'Low', 'Low', 'Low', 'High', 'Low', 'Low', 3.0], ['Low', 'Low', 'Medium', 'Medium', 'Medium', 'Low', 'Low', 'High', 'Low', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Medium', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 1.0], ['Low', 'Low', 'Very Low', 'Very Low', 'High', 'Low', 'Low', 'Low', 'Low', 'High', 'High', 'Low', 'High', 'Low', 'Low', 'High', 'Low', 'High', 'Low', 'Low', 'High', 'High', 3.0], ['Low', 'High', 'Low', 'Low', 'Medium', 'High', 'High', 'Low', 'High', 'High', 'Low', 'Low', 'Very Low', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Low', 'Low', 'High', 'High', 1.0], ['Low', 'Low', 'Very Low', 'Very Low', 'High', 'Low', 'High', 'Low', 'High', 'Low', 'Low', 'Low', 'Very Low', 'Low', 'Low', 'High', 'Medium', 'High', 'Low', 'High', 'High', 'High', 1.0], ['High', 'High', 'Low', 'Low', 'Medium', 'High', 'High', 'Low', 'High', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'High', 1.0], ['Low', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low', 'Very Low', 'Low', 'Medium', 'High', 'Low', 'Low', 'Low', 'High', 'Low', 'Low', 3.0], ['Low', 'Low', 'Medium', 'Medium', 'Medium', 'Low', 'Low', 'High', 'High', 'High', 'High', 'Medium', 'Medium', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'Low', 5.0], ['Low', 'Low', 'Very Low', 'Very Low', 'High', 'High', 'High', 'High', 'Low', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Medium', 'High', 'Medium', 'Low', 'Low', 'Low', 'High', 'Low', 4.0], ['Low', 'High', 'Medium', 'Medium', 'Medium', 'Low', 'Low', 'High', 'High', 'High', 'High', 'Medium', 'Medium', 'Low', 'Low', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 3.0], ['Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low', 'Very High', 'Low', 'Medium', 'Low', 'Low', 'Low', 'Low', 'High', 'High', 'Low', 3.0], ['Low', 'Low', 'Low', 'Low', 'High', 'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low', 'Very Low', 'Low', 'Medium', 'High', 'Medium', 'High', 'Low', 'High', 'High', 'High', 1.0], ['Low', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Low', 'High', 'High', 'High', 'High', 'Medium', 'Low', 'Medium', 'Medium', 'High', 'Medium', 'High', 'Medium', 'High', 'High', 'High', 1.0], ['Low', 'Low', 'Low', 'Low', 'High', 'High', 'Low', 'High', 'Low', 'High', 'High', 'Medium', 'Very Low', 'Low', 'Low', 'High', 'Medium', 'High', 'Medium', 'Low', 'High', 'High', 1.0], ['Low', 'Low', 'Low', 'Low', 'High', 'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low', 'Medium', 'Low', 'Medium', 'Low', 'Medium', 'Low', 'Low', 'Low', 'High', 'Low', 4.0], ['Low', 'Low', 'Very Low', 'Very Low', 'High', 'High', 'High', 'High', 'High', 'High', 'High', 'Low', 'High', 'Low', 'High', 'High', 'High', 'Low', 'High', 'Low', 'High', 'High', 2.0], ['Low', 'Low', 'Low', 'Low', 'Medium', ' ...

# %%
import time
start = time.time()
A = calculateA(base)
M = calculateM(base)
B = calculateB(base,A,M)
C = calculateC(base,B)
totalTime = time.time() - start
print(totalTime)
# Out:
# done A
# done B
# done C
# 14284.560707569122

# %%
# dfC = pd.DataFrame(C)
# dfC.to_csv('C.csv',index=False)
# traindf.to_csv('train.csv',index=False)
# testdf.to_csv('test.csv',index=False)

# %%
listAcc = []
listPre = []
listRe = []
timeTest = []
timeUpdate = []
listRank = []
res = []
testAccuracy(base,test,C)
print(listAcc)
print(listPre)
print(listRe)
# Out:
# [47.31]
# []
# []

# %%
# print(pd.DataFrame(res[0]).value_counts())
# print(traindf['Outcome'].value_counts())
# print(testdf['Outcome'].value_counts())
# print(pd.DataFrame(listRank).value_counts())
# print(len(listRank))
